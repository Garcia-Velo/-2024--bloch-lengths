# %% [markdown]
# # Importations

# %%
# Numerical and scientific python programming
import numpy as np

import matplotlib.pyplot as plt

# Auxiliary python functions
import time

# Local importations
from moments.bloch import compute_pauli_basis, compute_tensor_basis, compute_subset_index_map
from moments.optimization import optimize_moment_preserving_entanglement

# %% [markdown]
# # Hilbert apace definition

# %%
N = 2
d = 2 ** N

pauli_basis = compute_pauli_basis()
local_bases = [pauli_basis.copy()] * N
local_basis_sizes = [len(basis) for basis in local_bases]

tensor_basis = compute_tensor_basis(local_bases)
subset_index_map = compute_subset_index_map(local_basis_sizes)

# %% [markdown]
# ## Analytical conditions
#
# In general, the 3D region explored consits of a subset of $\mathbb R^3$ that satisfy certain constraints.
# In particular, those are
#
# - $x, y, z \ge 0$,
# - $z \ge x + y - 1$,
# - $z^2 \le 3 + x^2 + y^2 - 4xy - 4|x-y|$,
#
# By setting $y = 0$ the inequalities become:
#
# - $x, z \ge 0$,
# - $z \ge x - 1$,
# - $z^2 \le 3 + x^2 - 4x$.
#
# Similarly, we can first write down the iniqualities that difine the entangled, mixed and separable regions:
#
# - Entangled: $z^2 > 1 - |x^2 - y^2|$;
# - Separable: $z \le \begin{cases} \sqrt{\frac16 [2 - 3 (x + y)^2]} & x + y \le \frac23 \, , \\ 1 - x - y & \frac23 < x + y \le 1 \, ,  \\ x + y - 1 & 1 < x + y \, . \end{cases}$
#
# Which again can be simplified for the case of interest:
#
# - Entangled: $z^2 > 1 - x^2$;
# - Separable: $z \le \begin{cases} \sqrt{\frac16 [2 - 3 x^2]} & x \le \frac23 \, , \\ 1 - x & \frac23 < x \le 1 \, . \end{cases}$

# %%
x = np.linspace(0, 1, 1000)

z_upper = np.sqrt(3 - 4*x + x**2)
z_ent = np.sqrt(1 - x**2)
z_sep = np.piecewise(x, [x <= 2/3, x > 2/3],
                     [lambda x: np.sqrt(1/6 * (2 - 3 * x**2)), lambda x: 1 - x])
z_lower = np.zeros_like(x)

fig, ax = plt.subplots(figsize=(8, 9))

ax.fill_between(x, z_upper, z_ent, alpha=0.4, color='orange')
ax.fill_between(x, z_ent, z_sep, alpha=0.4, color='blue')
ax.fill_between(x, z_sep, z_lower, alpha=0.4, color='grey')

ax.plot(x, z_upper, 'red', label=r"$z = \sqrt{3 - 4x + x^2}$")
ax.plot(x, z_ent, 'orange', label=r"$z = 1 - x^2$")
ax.plot(x, z_sep, 'grey', label=f"$a$")
ax.plot(x, z_lower, 'blue', label=r"$z = 0$")



ax.set(xlabel = r'$x$', ylabel = r'$z$', title = 'Region at $y = 0$ plane',
       xlim = (0, 1.2), ylim = (0, 1.8))
ax.grid(True, alpha=0.5, linestyle="--")
ax.legend()
plt.show()

# %% [markdown]
# ## Moment space discretization

# %%
D = 200
Dx, Dz = D + 1, int(np.sqrt(3) * D) + 1

x = np.linspace(0, 1, Dx)
z = np.linspace(0, np.sqrt(3), Dz)

X, Z = np.meshgrid(x, z, indexing='ij')

mask_state = Z**2 <= 3 - 4*X + X**2
indices = np.where(mask_state)
total_points = len(indices[0])

points = np.column_stack((X[mask_state], Z[mask_state]))
print(f"Number of points: {points.shape[0]}")

sep_vals = np.full_like(X, np.nan)
sep_vals[X <= 2/3] = np.sqrt(1/6 * (2 - 3 * X[X <= 2/3]**2))
sep_vals[(X > 2/3)] = 1 - X[(X > 2/3)]

mask_ent = mask_state & (Z**2 > 1 - X**2)
mask_mix = (Z**2 <= 1 - X**2) & (Z > sep_vals)
mask_sep = Z <= sep_vals
# Out:
# Number of points: 43166

# %% [markdown]
# ## Optimization

# %%
def run_easy(d, tensor_basis, subset_index_map, Rt, optimization, max_attempts=5):
    result = None
    for _ in range(max_attempts):
        result = optimize_moment_preserving_entanglement(d, tensor_basis, subset_index_map, Rt,
                                                         metric="concurrence", optimization=optimization, cholesky_opt=True)
        if result.optimizer_info["result_success"]:
            return result
    return result

def run_hard(d, tensor_basis, subset_index_map, Rt, optimization, attempts):
    best_result = None
    best_metric = -np.inf

    for _ in range(attempts):
        result = optimize_moment_preserving_entanglement(d, tensor_basis, subset_index_map, Rt,
                                                         metric="concurrence", optimization=optimization, cholesky_opt=True)
        
        if result.metric_final > best_metric:
            best_metric = result.metric_final
            best_result = result

    return best_result

# %%
success, times = [], []
max_ent = np.full_like(X, np.nan, dtype=float)

for counter, (idx, jdx) in enumerate(zip(indices[0], indices[1]), 1):
    t0 = time.time()

    x_val = X[idx, jdx]
    z_val = Z[idx, jdx]

    Rt = {(1,): float(x_val), (2,): 0.0, (1, 2): float(z_val)}
    
    if mask_ent[idx, jdx]:
        optimization_result = run_easy(d, tensor_basis, subset_index_map, Rt, "maximize", max_attempts=5)

    elif mask_mix[idx, jdx]:
        optimization_result = run_hard(d, tensor_basis, subset_index_map, Rt, "maximize", attempts=10)

    elif mask_sep[idx, jdx]:
        optimization_result = run_easy(d, tensor_basis, subset_index_map, Rt, "maximize", max_attempts=5)

    else:
        continue
    
    max_ent[idx, jdx] = optimization_result.metric_final
    success.append(optimization_result.optimizer_info["result_success"])

    tf = time.time()

    times.append(tf-t0)
    
    percent_complete = (counter / total_points) * 100
    print(f"\rProgress: {percent_complete:.2f}% ({counter}/{total_points}) | Time for this point: {tf-t0:.3f} s", end="", flush=True)

print(f"\n\nDone!")
print(f"Successful optimizations: {sum(success)}/{total_points} | Percentage: {sum(success)*100/total_points:.2f} %")
print(f"Total time: {sum(times)/60:.2f} min | Average time per point: {sum(times)/total_points:.3f} s", )
# Out:
# Progress: 100.00% (43166/43166) | Time for this point: 2.422 s
#
# Done!
# Successful optimizations: 23233/43166 | Percentage: 53.82 %
# Total time: 829.73 min | Average time per point: 1.153 s

# %%
success, times = [], []
min_ent = np.full_like(X, np.nan, dtype=float)

for counter, (idx, jdx) in enumerate(zip(indices[0], indices[1]), 1):
    t0 = time.time()

    x_val = X[idx, jdx]
    z_val = Z[idx, jdx]

    Rt = {(1,): float(x_val), (2,): 0.0, (1, 2): float(z_val)}
    
    optimization_result = run_easy(d, tensor_basis, subset_index_map, Rt, "minimize", max_attempts=5)
    
    min_ent[idx, jdx] = optimization_result.metric_final
    success.append(optimization_result.optimizer_info["result_success"])

    tf = time.time()

    times.append(tf-t0)
    
    percent_complete = (counter / total_points) * 100
    print(f"\rProgress: {percent_complete:.2f}% ({counter}/{total_points}) | Time for this point: {tf-t0:.3f} s", end="", flush=True)

print(f"\n\nDone!")
print(f"Successful optimizations: {sum(success)}/{total_points} | Percentage: {sum(success)*100/total_points:.2f} %")
print(f"Total time: {sum(times)/60:.2f} min | Average time per point: {sum(times)/total_points:.3f} s", )
# Out:
# Progress: 13.92% (6009/43166) | Time for this point: 1.826 s s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 12
#       8     z_val = Z[idx, jdx]
#       9
#      10     Rt = {(1,): float(x_val), (2,): 0.0, (1, 2): float(z_val)}
#      11
# ---> 12     optimization_result = run_easy(d, tensor_basis, subset_index_map, Rt, "minimize", max_attempts=5)
#      13
#      14     min_ent[idx, jdx] = optimization_result.metric_final
#      15     success.append(optimization_result.optimizer_info["result_success"])
#
# Cell In[5], line 4, in run_easy(d, tensor_basis, subset_index_map, Rt, optimization, max_attempts)
#       1 def run_easy(d, tensor_basis, subset_index_map, Rt, optimization, max_attempts=5):
#       2     result = None
#       3     for _ in range(max_attempts):
# ----> 4         result = optimize_moment_preserving_entanglement(d, tensor_basis, subset_index_map, Rt,
#       5                                                          metric="concurrence", optimization=optimization, cholesky_opt=True)
#       6         if result.optimizer_info["result_success"]:
#       7             return result
#
# File ~/Documents/projects/entanglement-optimization/src/moments/optimization.py:388, in optimize_moment_preserving_entanglement(d, tensor_basis, subset_index_map, Rt, metric, optimization, cholesky_opt, purity_tol, psd_tol, jac_tol, local_maxiter)
#     381     constraints.append({
#     382         "type": "eq",
#     383         "fun": compute_constraints_fun(subset),
#     384         "jac": compute_constraints_jac(i),
#     385     })
#     387 # --- 7. Run optimization ---
# --> 388 result = minimize(objective, x0,
#     389     method="SLSQP", constraints=constraints,
#     390     options={
#     391         "maxiter": local_maxiter,
#     392         "ftol": 1e-12,
#     393         "disp": False
#     394     }
#     395 )
#     397 # --- 8. Extract final state ---
#     398 cache_result = compute_shared(result.x)
#
# File ~/Documents/projects/entanglement-optimization/.venv/lib/python3.14/site-packages/scipy/optimize/_minimize.py:796, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     793     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     794                            **options)
#     795 elif meth == 'slsqp':
# --> 796     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     797                           constraints, callback=callback, **options)
#     798 elif meth == 'trust-constr':
#     799     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     800                                        bounds, constraints,
#     801                                        callback=callback, **options)
#
# File ~/Documents/projects/entanglement-optimization/.venv/lib/python3.14/site-packages/scipy/optimize/_slsqp_py.py:529, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, workers, **unknown_options)
#     527 if state_dict['mode'] == -1:  # gradient evaluation required
#     528     g = sf.grad(x)
# --> 529     _eval_con_normals(C, x, cons, m, meq)
#     531 if state_dict['iter'] > iter_prev:
#     532     # call callback if major iteration has incremented
#     533     if callback is not None:
#
# File ~/Documents/projects/entanglement-optimization/.venv/lib/python3.14/site-packages/scipy/optimize/_slsqp_py.py:601, in _eval_con_normals(C, x, cons, m, meq)
#     599 row = 0
#     600 for con in cons['eq']:
# --> 601     temp = np.atleast_2d(con['jac'](x, *con['args']))
#     602     C[row:row + temp.shape[0], :] = temp
#     603     row += temp.shape[0]
#
# File ~/Documents/projects/entanglement-optimization/src/moments/optimization.py:377, in optimize_moment_preserving_entanglement.<locals>.compute_constraints_jac.<locals>.jac(x)
#     376 def jac(x):
# --> 377     return compute_jacobian(x)[i]
#
# File ~/Documents/projects/entanglement-optimization/src/moments/optimization.py:325, in optimize_moment_preserving_entanglement.<locals>.compute_jacobian(x)
#     309 def compute_jacobian(x: np.ndarray) -> np.ndarray:
#     310     """
#     311     Calculates the Jacobian of the objective function.
#     312     Results are cached in the shared data dictionary to avoid redundant computations.
#    (...)    323         Each row corresponds to the gradient of one constraint with respect to all variables.
#     324     """
# --> 325     data = compute_shared(x)
#     327     if data["jac"] is not None:
#     328         return data["jac"]
#
# File ~/Documents/projects/entanglement-optimization/src/moments/optimization.py:262, in optimize_moment_preserving_entanglement.<locals>.compute_shared(x)
#     236 def compute_shared(x: np.ndarray) -> Dict:
#     237     """
#     238     Compute and cache quantum state representations and derived quantities to avoid redundant calculations.
#     239
#    (...)    260             Placeholder for Jacobian (reset on cache update).
#     261     """
# --> 262     if "x" not in cache or not np.array_equal(x, cache["x"]):
#     263         X = compute_X_from_param(x, cholesky_opt)
#     264         rho = compute_dm_from_X(X)
#
# File ~/Documents/projects/entanglement-optimization/.venv/lib/python3.14/site-packages/numpy/_core/numeric.py:2601, in array_equal(a1, a2, equal_nan)
#    2599     return False
#    2600 if not equal_nan:
# -> 2601     return builtins.bool((asanyarray(a1 == a2)).all())
#    2603 if a1 is a2:
#    2604     # nan will compare equal so an array will compare equal to itself.
#    2605     return True
#
# File ~/Documents/projects/entanglement-optimization/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:70, in _all(a, axis, dtype, out, keepdims, where)
#      68 # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      69 if where is True:
# ---> 70     return umr_all(a, axis, dtype, out, keepdims)
#      71 return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Results

# %%
fig, ax = plt.subplots(1, 2, figsize=(17, 10), constrained_layout=True, dpi=300)

mesh0 = ax[0].pcolormesh(X, Z, max_ent, shading='auto', cmap='viridis', vmin=0, vmax=1)
#mesh1 = ax[1].pcolormesh(X, Z, min_ent, shading='auto', cmap='viridis', vmin=0, vmax=1)

cbar = fig.colorbar(mesh0, ax=ax.ravel().tolist(), label='Entanglement', 
                    pad=0.05, aspect=20, shrink=1)

cbar.set_ticks(list(np.linspace(0, 1, 6)))

ax[0].set(xlabel = r"$|| r_1 ||$", ylabel = r"$||r_{1, 2}||$",
xlim = (0, 1.2), ylim = (0, 1.8))
ax[1].set(xlabel = r"$|| r_1 ||$", ylabel = r"$||r_{1, 2}||$",
xlim = (0, 1.2), ylim = (0, 1.8))

ax[0].set_title('Maximum Entanglement')
ax[1].set_title('Minimum Entanglement')

x = np.linspace(0, 1, 1000)
z_upper = np.sqrt(3 - 4*x + x**2)
z_ent = np.sqrt(1 - x**2)
z_sep = np.piecewise(x, [x <= 2/3, x > 2/3],
                     [lambda x: np.sqrt(1/6 * (2 - 3 * x**2)), lambda x: 1 - x])
z_lower = np.zeros_like(x)

ax[0].plot(x, z_sep, 'darkgrey', linewidth=3, label='Separable')
ax[0].plot(x, z_ent, 'orange', linewidth=3, label='Entangled')
ax[0].plot(x, z_upper, 'r', linewidth=3, label='Upper bound')
ax[0].plot(x, z_lower, 'b', linewidth=3, label='Lower bound')

ax[1].plot(x, z_sep, 'darkgrey', linewidth=3, label='Separable')
ax[1].plot(x, z_ent, 'orange', linewidth=3, label='Entangled')
ax[1].plot(x, z_upper, 'r', linewidth=3, label='Upper bound')
ax[1].plot(x, z_lower, 'b', linewidth=3, label='Lower bound')

ax[0].legend(loc='upper right')
ax[0].grid(True, alpha=0.3)
ax[1].grid(True, alpha=0.3)

plt.show()

# %%
np.save("max_concurrence", max_ent)
#np.save("mix_concurrence_2q_xz_plane", min_ent)
